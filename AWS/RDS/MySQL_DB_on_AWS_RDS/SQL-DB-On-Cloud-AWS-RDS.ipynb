# %%
# !pip install mysql-connector-python boto3
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
USER='admin'
PASSWORD='gh45mod7=78%()'
HOST='my-first-db.c3sukmmcsitj.ap-south-1.rds.amazonaws.com'

# %% [markdown]
# # Test Connection

# %%
import mysql.connector
import boto3

conn = None
try:
    conn = mysql.connector.connect(
        host=HOST,
        port=3306,
        database='mysql',
        user=USER,
        password=PASSWORD,
        ssl_disabled=False,
        autocommit=True,
    ssl_ca='./global-bundle.pem'
    )
    cur = conn.cursor()
    cur.execute('SELECT VERSION();')
    print(cur.fetchone()[0])
    cur.close()
except Exception as e:
    print(f"Database error: {e}")
    raise
finally:
    if conn:
        conn.close()
# Out:
# 8.4.7

# %% [markdown]
# # Create a DB

# %%
import mysql.connector
import boto3

conn = None
try:
    conn = mysql.connector.connect(
        host=HOST,
        port=3306,
        database='mysql',
        user=USER,
        password=PASSWORD,
        ssl_disabled=False,
        autocommit=True,
    ssl_ca='./global-bundle.pem'
    )
    cur = conn.cursor()

    cur.execute("CREATE DATABASE student_db;")
    print("Success")
    cur.close()
except Exception as e:
    print(f"Database error: {e}")
    raise
finally:
    if conn:
        conn.close()
# Out:
# Success

# %% [markdown]
# # Run few queries

# %%
# !pip install pymysql
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymysql

# %% [markdown]
# # Create Table

# %%
connection = pymysql.connect(
    host=HOST,
    user=USER,
    password=PASSWORD,
    database="student_db",
    port=3306
)

cursor = connection.cursor()

create_table_query = """
CREATE TABLE IF NOT EXISTS students (
    id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(100),
    course VARCHAR(100)
)
"""

cursor.execute(create_table_query)

connection.commit()

print("Table created successfully")

cursor.close()
connection.close()
# Out:
# Table created successfully

# %% [markdown]
# # Insert records

# %%
import pymysql

connection = pymysql.connect(
    host=HOST,
    user=USER,
    password=PASSWORD,
    database="student_db",
    port=3306
)

cursor = connection.cursor()

query = """
INSERT INTO students (name, course)
VALUES (%s,%s)
"""

data = ("Alice", "Machine Learning")
cursor.execute(query, data)
connection.commit()
print("Data inserted")

cursor.close()
connection.close()
# Out:
# Data inserted

# %% [markdown]
# # Retrieve records

# %%
import pymysql

connection = pymysql.connect(
    host=HOST,
    user=USER,
    password=PASSWORD,
    database="student_db",
    port=3306
)

cursor = connection.cursor()

cursor.execute("SELECT * FROM students")
rows = cursor.fetchall()

for r in rows:
    print(r)

cursor.close()
connection.close()
# Out:
# (1, 'Alice', 'Machine Learning')

# %%
# Now we drop the DB

# %%
connection = pymysql.connect(
    host=HOST,
    user=USER,
    password=PASSWORD,
    database="student_db",
    port=3306
)

cursor = connection.cursor()

cursor.execute("DROP DATABASE student_db")

connection.commit()

print("DB Dropped successfully")

cursor.close()
connection.close()
# Out:
# DB Dropped successfully
