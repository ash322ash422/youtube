# %% [markdown]
# #### How to use Pre-trained Model?
#
# ##### ResNet --> Classifications

# %%
# Basic imports for TensorFlow and Keras
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
# Imports for Pre-trainned models

from keras.applications.resnet50 import ResNet50

model = ResNet50(
    weights = 'imagenet'
    )
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
# Image path

path ='E:\\UCT Training AIMLDS\\GENAI_IITG_6Months\\cat.jpg'

# %%
# Image preprocessing

from keras.applications.resnet50 import preprocess_input
from keras.applications.resnet50 import decode_predictions

# %%
img = keras.utils.load_img(path, target_size=(224, 224))
x = keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x
# Out:
# array([[[[-11.939003, -17.779   , -27.68    ],
#          [-13.939003, -21.779   , -30.68    ],
#          [-16.939003, -28.779   , -37.68    ],
#          ...,
#          [ -9.939003, -18.779   , -20.68    ],
#          [ -7.939003, -17.779   , -16.68    ],
#          [ -7.939003, -18.779   , -15.68    ]],
#
#         [[-12.939003, -19.779   , -27.68    ],
#          [-11.939003, -19.779   , -27.68    ],
#          [-15.939003, -27.779   , -36.68    ],
#          ...,
#          [-15.939003, -23.779   , -27.68    ],
#          [-14.939003, -22.779   , -26.68    ],
#          [-16.939003, -24.779   , -28.68    ]],
#
#         [[ -7.939003, -17.779   , -20.68    ],
#          [-11.939003, -19.779   , -23.68    ],
#          [-16.939003, -29.779   , -36.68    ],
#          ...,
#          [-20.939003, -31.779   , -38.68    ],
#          [-22.939003, -33.779   , -40.68    ],
#          [-23.939003, -34.779   , -41.68    ]],
#
#         ...,
#
# ...

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
preds
# Out:
# array([[8.03861383e-07, 1.21418475e-06, 5.09647577e-07, 2.81570635e-07,
#         3.46279444e-06, 1.14844067e-06, 7.07711820e-07, 9.38411176e-07,
#         1.35170321e-05, 1.86380548e-05, 4.51103006e-07, 5.59655837e-06,
#         1.22124777e-06, 4.28800740e-06, 2.47493091e-07, 2.72484340e-06,
#         1.81008181e-05, 2.84890348e-06, 5.14625117e-06, 1.53935375e-07,
#         2.05785673e-05, 1.44932801e-05, 8.29322598e-05, 9.96127528e-06,
#         9.94810398e-05, 1.18536768e-07, 1.88676992e-07, 1.06619848e-06,
#         1.45494795e-07, 2.30631912e-07, 7.87572117e-06, 3.59450246e-06,
#         4.02080786e-07, 3.50698429e-07, 9.98968744e-07, 3.17643639e-06,
#         3.26159011e-06, 4.15857721e-06, 2.37871882e-06, 6.63900801e-06,
#         1.28559998e-06, 2.90848902e-06, 7.53034954e-07, 2.70651481e-06,
#         1.45733293e-06, 3.41575600e-07, 1.31169845e-05, 6.81616314e-07,
#         5.35554591e-07, 1.26500845e-06, 1.50805113e-06, 2.53322924e-06,
# ...

# %%
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n02123045', 'tabby', np.float32(0.8169201)), ('n02123159', 'tiger_cat', np.float32(0.112012915)), ('n02124075', 'Egyptian_cat', np.float32(0.02458259))]

# %%
img2 = keras.utils.load_img('E:\\UCT Training AIMLDS\\GENAI_IITG_6Months\\bot.jpg', target_size=(224, 224))
x = keras.utils.img_to_array(img2)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n04560804', 'water_jug', np.float32(0.32467604)), ('n04557648', 'water_bottle', np.float32(0.23563695)), ('n03476991', 'hair_spray', np.float32(0.19685443))]
