# %%
# Import regex module
import re

# %%
re?
# Out:
# Type:        module
# String form: <module 're' from 'C:\\Users\\hi\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\re\\__init__.py'>
# File:        c:\users\hi\appdata\local\programs\python\python311\lib\re\__init__.py
# Docstring:
# Support for regular expressions (RE).
#
# This module provides regular expression matching operations similar to
# those found in Perl.  It supports both 8-bit and Unicode strings; both
# the pattern and the strings being processed can contain null bytes and
# characters outside the US ASCII range.
#
# Regular expressions can contain both special and ordinary characters.
# Most ordinary characters, like "A", "a", or "0", are the simplest
# regular expressions; they simply match themselves.  You can
# concatenate ordinary characters, so last matches the string 'last'.
#
# The special characters are:
#     "."      Matches any character except a newline.
#     "^"      Matches the start of the string.
# ...

# %%
text = "email 3 address of 4 loxford is bikes@gmail.fort and loxford@yahoo.com"

# %%
results = re.findall("\@",text)
print(results)
# Out:
# ['@', '@']

# %%
# Matches any character except a newline.
results = re.findall(".",text)
results
# Out:
# ['e',
#  'm',
#  'a',
#  'i',
#  'l',
#  ' ',
#  'a',
#  'd',
#  'd',
#  'r',
#  'e',
#  's',
#  's',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'l',
#  'o',
#  'x',
#  'f',
#  'o',
#  'r',
#  'd',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'b',
#  'i',
#  'k',
#  'e',
#  's',
#  '@',
#  'g',
#  'm',
#  'a',
#  'i',
#  'l',
#  '.',
#  'f',
#  'o',
#  'r',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'l',
#  'o',
#  'x',
#  'f',
#  'o',
#  'r',
#  'd',
#  '@',
#  'y',
#  'a',
#  'h',
#  'o',
#  'o',
#  '.',
#  'c',
#  'o',
#  'm']

# %%
text = "All 3 friends had 4 kids and 2 donkeys"
pattern = r"(\d)" # find all digits
output = re.findall(pattern, text)

print(output)
# Out:
# ['3', '4', '2']

# %%
text = "He made profit of 545 bucks"
pattern = r"(\d)"

output = re.findall(pattern, text)
print(output)
# Out:
# ['5', '4', '5']

# %%
text = "He made profit of 545 bucks"
pattern = r"(\d+)"

output = re.findall(pattern, text)
print(output)
# Out:
# ['545']

# %%
text = "He made profit of 545 bucks. Is this True ?"

pattern = r"(\w+)"

output = re.findall(pattern, text)

print(output)
# Out:
# ['He', 'made', 'profit', 'of', '545', 'bucks', 'Is', 'this', 'True']

# %%
text = "He made profit of 545 bucks. Is this True ?  "

pattern = r"(\D)"

output = re.findall(pattern, text)

print(output)
# Out:
# ['H', 'e', ' ', 'm', 'a', 'd', 'e', ' ', 'p', 'r', 'o', 'f', 'i', 't', ' ', 'o', 'f', ' ', ' ', 'b', 'u', 'c', 'k', 's', '.', ' ', 'I', 's', ' ', 't', 'h', 'i', 's', ' ', 'T', 'r', 'u', 'e', ' ', '?', ' ', ' ']

# %%
text = "He made profit of 545 bucks. Is this True ?  "

pattern = r"(\w)"

output = re.findall(pattern, text)

print(output)
# Out:
# ['H', 'e', 'm', 'a', 'd', 'e', 'p', 'r', 'o', 'f', 'i', 't', 'o', 'f', '5', '4', '5', 'b', 'u', 'c', 'k', 's', 'I', 's', 't', 'h', 'i', 's', 'T', 'r', 'u', 'e']

# %%
# Find word that starts with 'p' and ends with 't'
text = "He made profit of 545 bucks. Is this True ?  "
pattern = r"\bp\w+t\b"

output = re.findall(pattern, text)

print(output)
# Out:
# ['profit']

# %%
# word start with p and b
text = "He made profit of 545 bucks. Is this bucks True ?  "
pattern = r"\b[pb]\w+"

output = re.findall(pattern, text)

print(output)
# Out:
# ['profit', 'bucks', 'bucks']

# %% [markdown]
# #### Class-work

# %%
# Get email addresses from a text

text = "Please contact me at abracadbra@gmail.com"

pattern = r"\w+@\w+"

output = re.findall(pattern, text)

print(output)
# Out:
# ['abracadbra@gmail']

# %%
text = "Please contact me at abracadbra@gmail.com"

pattern = r"\w+@\w+\.\w+"

output = re.findall(pattern, text)

print(output)
# Out:
# ['abracadbra@gmail.com']

# %%
text = 'purple alice-b@google.com monkey dishwasher'

pattern = r'[\w\.-]+@[\w\.-]+'

output = re.findall(pattern, text)

print(output)
# Out:
# ['alice-b@google.com']

# %%
#Extract all phone numbers from a string
# "The phone numbers are +91-9876543210, 9876543210, and (+91) 9876543210."

text = "The phone numbers are +91-9876543210, 9876543210, and (+91) 9876543210."

pattern = r"[+]+\d{1,3}[-\s]?\d{10}|\(?\d{3}\)?[-\s]?\d{3}[-\s]?\d{4}"

output = re.findall(pattern, text)

print(output)
# Out:
# ['+91-9876543210', '9876543210', '9876543210']

# %%
text = "The phone numbers are +91-9876543210, 9876543210, and (+91) 9876543210."

pattern = r"(?:\+91[-]?|\(\+91\)\s?)?\d{10}"

output = re.findall(pattern, text)

print(output)
# Out:
# ['+91-9876543210', '9876543210', '(+91) 9876543210']

# %%
# re.search()

text = "Python is powerful."

pattern = r"powerful"

match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(10, 18), match='powerful'>

# %%
if match:
    print("Found:", match)
    print("\n")
    print("Found: ", match.group())
else:
    print("Not found")
# Out:
# Found: <re.Match object; span=(10, 18), match='powerful'>
#
#
# Found:  powerful

# %%
match
# Out:
# <re.Match object; span=(10, 18), match='powerful'>

# %%
# re.search()

text = "Python is powerful is more powerful."

pattern = r"powerful"

match = re.search(pattern, text)

if match:
    print("Found:", match)
    print("\n")
    print("Found: ", match.group())
else:
    print("Not found")
# Out:
# Found: <re.Match object; span=(10, 18), match='powerful'>
#
#
# Found:  powerful

# %%
# re.search()

text = "Python is powerful is more powerful."

pattern = r"powerful"

match = re.search(pattern, text)

if match:
    print("Found:", match)
    print("\n")
    print("Found: ", match.group())
    print("Start index:", match.start())
    print("End index:", match.end())
else:
    print("Not found")
# Out:
# Found: <re.Match object; span=(10, 18), match='powerful'>
#
#
# Found:  powerful
# Start index: 10
# End index: 18

# %%
text = "My number is 12345."

pattern = r"\d+"
match = re.search(pattern, text)

print(match.group())
# Out:
# 12345

# %%
text = "My number is 12345-678910."

pattern = r"\d+-\d+"
match = re.search(pattern, text)

print(match.group())
# Out:
# 12345-678910

# %%
text = "Date: 2025-06-10"

pattern = r"(\d{4})-(\d{2})-(\d{2})"

match = re.search(pattern, text)

if match:
    print("Year:", match.group(1))
    print("Month:", match.group(2))
    print("Day:", match.group(3))
# Out:
# Year: 2025
# Month: 06
# Day: 10

# %%
match
# Out:
# <re.Match object; span=(6, 16), match='2025-06-10'>

# %%
# re.sub()

text = "I love cats. Cats are cute."
new_text = re.sub(r"cats", "dogs", text)
print(new_text)
# Out:
# I love dogs. Cats are cute.

# %%
text = "I love cats. Cats are cute."
new_text = re.sub(r"cats", "dogs", text, flags=re.IGNORECASE)
print(new_text)
# Out:
# I love dogs. dogs are cute.

# %%
# Remove extra spaces from a string
text = "Python    is    great!"
cleaned = re.sub(r"\s+", " ", text)
print(cleaned)
# Out:
# Python is great!

# %%
# Masking phone numbers in a string
text = "Call me at 9876543210 or 9123456789."
masked = re.sub(r"\d{6}(\d{4})", r"******\1", text)
print(masked)
# Out:
# Call me at ******3210 or ******6789.

# %%
# Remove HTML tags from a string
html = "<div>Hello</div><p>World</p>"
text = re.sub(r"<.*?>", "", html)
print(text)
# Out:
# HelloWorld

# %%
# Remove HTML tags from a string
html = "<div>Hello</div><p>World</p>"
text = re.sub(r"<.*>", "", html)
print(text)

# %%
# Remove HTML tags from a string
html = "<div>Hello</div><p>World</p>"
text = re.sub(r"<.*?>", " ", html)
print(text)
# Out:
#  Hello  World

# %%
# Replace first two occurrences of "two" with "2"
text = "one two three two four two"
result = re.sub(r"two", "2", text, count=2)
print(result)
# Out:
# one 2 three 2 four two

# %%
# Match
output = re.match(r"\d+", "123abc")
print(output.group())
# Out:
# 123

# %%
# Match
output = re.match(r"\d+", "abc123")
print(output)
print(output.group())
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1822865187.py in <cell line: 0>()
#       2 output = re.match(r"\d+", "abc123")
#       3 print(output)
# ----> 4 print(output.group())
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
output = re.fullmatch(r"\d+", "123456")

print(output.group())
# Out:
# 123456

# %%
output = re.fullmatch(r"\d+", "123abc")

print(output)  # Should be None since it doesn't match the entire string
# Out:
# None

# %%
# re.split()


output = re.split(r"\s", "Split this   string")

print(output)
# Out:
# ['Split', 'this', '', '', 'string']

# %%
output = re.split(r"\s+", "Split this   string")

print(output)
# Out:
# ['Split', 'this', 'string']

# %%
# re.compile() - Compile a pattern into a Pattern object - Compiles a regex pattern into a reusable object.

pattern = re.compile(r"\d+")
pattern.findall("123 456")
# Out:
# ['123', '456']

# %%
# email pattern with re.compile()

pattern = re.compile(r"[\w\.-]+@[\w\.-]+")
text = "Please contact me at anantv0@gmail.com and abc-34d@gmail.com"
output = pattern.findall(text)
print(output)
# Out:
# ['anantv0@gmail.com', 'abc-34d@gmail.com']
