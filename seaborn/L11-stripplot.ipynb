# %% [markdown]
# # stripplot
#
#
# A strip plot displays **individual data points** for a numerical variable across categories.
#
# - Strip plot shows every single observation.
# - Do NOT use Strip Plot for very large datasets

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
tips = sns.load_dataset("tips")

# Display first few rows
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(
    data=tips,
    y="total_bill" # numerical
)

plt.title("Strip Plot of Total Bill")
plt.show()

# %% [markdown]
# # Observation:
# - Each dot is a data point
# - Most of data is between 10 and 25

# %% [markdown]
# # Compare with boxplot

# %%
# Create figure with 2 columns
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Stripplot
sns.stripplot(
    data=tips,
    y="total_bill",
    ax=axes[0]
)
axes[0].set_title("Strip Plot")

# Boxplot
sns.boxplot(
    data=tips,
    y="total_bill",
    ax=axes[1]
)
axes[1].set_title("Box Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation:
# - 25% of data lies below 14(approx)
# - 50% of data lies below 18(approx)
# - 75% of data lies below 24(approx)
# - If number of points increase to 100,000, then strip plot would become cluttered. In this case, box plot would be appropriate

# %% [markdown]
# # Seperate total_bill by day

# %%
# Now lets add category day

sns.stripplot(
    data=tips,
    x="day", # category
    y="total_bill"
)

plt.title("Strip Plot of Total Bill per Day")
plt.show()

# %% [markdown]
# Each dot = one customer
#
# Vertical spread = distribution
#
# # Observation:
# - Not many custoomers on Fri

# %%
# Add jitter to prevent points overlap.

sns.stripplot(
    data=tips,
    x="day", # category
    y="total_bill",
    jitter=True
)

plt.title("Strip Plot with Jitter")
plt.show()

# %% [markdown]
# # Show total_bill by day and time

# %%
# jitter
sns.stripplot(
    data=tips,
    x="day", # category
    y="total_bill",
    hue="time", # category
    jitter=True
)

plt.title("Total Bill per Day by time")
plt.show()

# %% [markdown]
# # observation:
# - All customers on Sat and Sun are for Dinner
# - More customers for Lunch on Thur

# %%
# or seperate the points for time
sns.stripplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="time", # category
    dodge=True
)

plt.title("Total Bill per Day by time")
plt.show()
