# %% [markdown]
# # ML Overview
# The iris dataset contains dimensions of flowers and a target variable indicating type of flower: setosa, versicolor and virginica
#
# 1) Collect Data
# 2) Split Data --> training + testing
# 3) Train the model on training dataset
# 4) Evaluate the model on test dataset

# %%
import pandas as pd

# 1. LOAD DATASET
df = pd.read_csv("iris.csv")

X = df[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
y = df['species']

print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (150, 5)

# %%
print(df.sample(10))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 126           6.2          2.8           4.8          1.8   virginica
# 130           7.4          2.8           6.1          1.9   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 103           6.3          2.9           5.6          1.8   virginica
# 90            5.5          2.6           4.4          1.2  versicolor
# 113           5.7          2.5           5.0          2.0   virginica
# 23            5.1          3.3           1.7          0.5      setosa
# 76            6.8          2.8           4.8          1.4  versicolor
# 27            5.2          3.5           1.5          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa

# %%
print(X.head(10))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4
# 6           4.6          3.4           1.4          0.3
# 7           5.0          3.4           1.5          0.2
# 8           4.4          2.9           1.4          0.2
# 9           4.9          3.1           1.5          0.1

# %%
print(y[:10])
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# 5    setosa
# 6    setosa
# 7    setosa
# 8    setosa
# 9    setosa
# Name: species, dtype: object

# %%
# 2. SPLIT DATA INTO TRAINING AND TESTING

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("shape of X_train:", X_train.shape)
print("shape of X_test :", X_test.shape)
# Out:
# shape of X_train: (120, 4)
# shape of X_test : (30, 4)

# %%
# 3. TRAIN THE MODEL
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Lets make prediction on 2 samples that I copied
#       sepal length, sepal width, petal length, petal width
X_sample = [[5.1, 3.5, 1.4, 0.2],  # actual data is setosa
            [6.3, 3.3, 6  , 2.5],  # actual data is virginica
           ] 

X_df = pd.DataFrame(sample, columns=X_train.columns)

prediction = model.predict(sample_df)
print("Prediction:", prediction)
# Out:
# Prediction: ['setosa' 'virginica']

# %%
# 4. FEED THE TEST DATA X_test

y_pred = model.predict(X_test)

# %%
# 5. EVALUATE THE MODEL
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.9333333333333333
