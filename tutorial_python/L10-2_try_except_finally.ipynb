# %% [markdown]
# # Catching errors using **try - except - finally**
# - Handle errors gracefully
# - Display customized error message

# %% [raw]
# Exception
# │
# ├── ArithmeticError
# │   ├── ZeroDivisionError
# │
# ├── ValueError
# ├── TypeError
# ├── IndexError
# ├── KeyError
# ├── NameError
# ├── AttributeError
# ├── FileNotFoundError
# ├── ImportError
# ├── ModuleNotFoundError
# ├── RuntimeError
# ├── OverflowError
# ├── PermissionError

# %%
# 1) Lets divide 10 by 5
a = 10
b = 5

x = a / b

print("result:", x)
print("Program continues running hereon.")
# Out:
# result: 2.0
# Program continues running hereon.

# %%
# 2) Now we divide 10 by 0 and get error
a = 10
b = 0

x = a / b

print("result:", x)
print("Program continues running hereon.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 a = 10
#       3 b = 0
# ----> 5 x = a / b
#       7 print("result:", x)
#       8 print("Program continues running hereon.")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Lets catch this error

# %%
# 3) 
a = 10
b = 0

try:
    x = a / b  # This will raise a ZeroDivisionError
    print("result:", x)
    
except ZeroDivisionError:    # this will catch the error 
    print("An error occurred! Please do not divide by 0")
    
print("Program continues running hereon.")
# Out:
# An error occurred! Please do not divide by 0
# Program continues running hereon.

# %%
# 2

# %% [markdown]
# ## Catch more than 1 errors

# %%
# 1) Following can generate 2 errors (ZeroDivisionError, ValueError)

num = int(input("Enter a number: "))

result = 100 / num

print(f"100 divided by {num} is {result}")
# Out:
# Enter a number:  gfdgfd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # 1) Following can generate 2 errors (ZeroDivisionError, ValueError)
# ----> 3 num = int(input("Enter a number: "))
#       5 result = 100 / num
#       7 print(f"100 divided by {num} is {result}")
#
# ValueError: invalid literal for int() with base 10: 'gfdgfd'

# %%
# 2) Fix: Catch specific exceptions

try:
    num = int(input("Enter a number: "))
    result = 100 / num
    print(f"100 divided by {num} is {result}")
    
except ZeroDivisionError: 
    print("Error: You cannot divide by zero!")
    
except ValueError:      # user did not entered number
    print("Error: You must enter a valid number!")

print("Thank you")
# Out:
# Enter a number:  fsdfsf
# Error: You must enter a valid number!
# Thank you

# %%
# 1) Example of 2 errors: IndexError, ValueError

numbers = [10, 20, 30, 40]
index = int(input("Enter an index (0–3): "))
print("Value:", numbers[index])
# Out:
# Enter an index (0–3):  gfdgfd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       1 # 1) Example of 2 errors: IndexError, ValueError
#       3 numbers = [10, 20, 30, 40]
# ----> 4 index = int(input("Enter an index (0–3): "))
#       5 print("Value:", numbers[index])
#
# ValueError: invalid literal for int() with base 10: 'gfdgfd'

# %%
# 2) Catch 2 errors: IndexError, ValueError

numbers = [10, 20, 30, 40]

try:
    index = int(input("Enter an index (0–3): "))
    print("Value:", numbers[index])

except IndexError:
    print("Index out of range. Please choose between 0 and 3.")

except ValueError:       # user did not entered number
    print("Please enter a valid integer.")

print("Thank you")
# Out:
# Enter an index (0–3):  fdsfds
# Please enter a valid integer.
# Thank you

# %%
# 3

# %% [markdown]
# ## Catch all runtime errors: Risky

# %%
try:
    # risky code
    x = int(input("Enter a number: "))
    print(10 / x)

except Exception as e:
    print("An error occurred:", e)
# Out:
# Enter a number:  5
# 2.0

# %% [markdown]
# ### Why this is bad:
#
# Hides the real error
#
# Makes debugging difficult
#
# Catches system-level exceptions unintentionally

# %% [markdown]
# ## Using **finally**
#
# The **finally** block always runs, whether an error occurs or not.

# %%
# 1) Lets find error if file does not exist
file = open("dummy.txt", "r")
content = file.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 2
#       1 # 1) Lets find error if file does not exist
# ----> 2 file = open("dummy.txt", "r")
#       3 content = file.read()
#       4 print(content)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dummy.txt'

# %%
# Lets catch above error:

try:
    file = open("dummy.txt", "r")
    content = file.read()
    print(content)
    
except FileNotFoundError:
    print("File not found.")
    
finally:
    print("Execution completed.")
# Out:
# File not found.
# Execution completed.

# %% [markdown]
# # STOP
