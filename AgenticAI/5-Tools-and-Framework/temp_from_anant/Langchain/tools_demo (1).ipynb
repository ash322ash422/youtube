# %%
print("Everything is okay!")
# Out:
# Everything is okay!

# %% [markdown]
# Tools - Built-in tools
#
#
# Custom tools

# %% [markdown]
# #### DuckDuckGo Search Tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

search.invoke("Who won the toss in Today's April 11 2026 IPL?")
# Out:
# '1 day ago ·Rajasthan Royals (RR) thumped Royal Challengers Bengaluru (RCB) by 6 wickets with 12 balls to spare in match 16 of the Indian Premier League at the Barsapara Cricket Stadium on Friday,April11,2026. 5 hours ago ·IPL2026, SRH vs PBKSTodayMatch: Punjab Kings captain Shreyas Iyerwonthe tossand elected to bowl first against Sunrisers Hyderabad in Match 17 of the Indian Premier League (IPL)2026at the Maharaja Yadavindra Singh International Cricket Stadium in Mullanpur, New Chandigarh on Saturday,April11,2026. View allIPL2026matchresultswith detailed scorecards and summaries. Stay updated with every match outcome on IPLT20. 5 hours ago ·PBKS vs SRHIPL2026TossLIVE, Punjab Kings vs Sunrisers Hyderabad TimingTodayMatch (पंजाब किंग्स बनाम सनराइजर्स हैदराबाद आज का टॉस कौन जीता), क्रिकेट News, Times Now Navbharat. 15 hours ago ·Catch the fastest live cricket scores and ball-by-ball commentary. Get real-time updates, full scorecards, and match analysis for theIPL2026& all global and domestic series.'

# %%
#Basic information 
print(search.name)
# Out:
# duckduckgo_search

# %%
#Basic information 
print(search.description)
# Out:
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.

# %%
#Basic information 
print(search.args)
# Out:
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# - All tools are Runnable means with all tools we can us .invoke function to get the result/response.

# %% [markdown]
# ### Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke("dir")

print(result)
# Out:
# Executing command:
#  dir
#  Volume in drive D is New Volume
#  Volume Serial Number is D610-0FE2
#
#  Directory of d:\GENAIBatch\langchain_new\tools
#
# 11-04-2026  08:49 PM    <DIR>          .
# 11-04-2026  08:49 PM    <DIR>          ..
# 11-04-2026  09:04 PM            36,128 tools_demo.ipynb
#                1 File(s)         36,128 bytes
#                2 Dir(s)  202,161,700,864 bytes free

# %% [markdown]
# - The ability to execute commands directly within a system's Bash shell
# - It is primarily used to bridge the gap between an agent's reasoning and the local operating system, allowing it to perform tasks that would otherwise require manual terminal input.

# %%
# Basic information 
print(shell_tool.name)
print(shell_tool.description)
print(shell_tool.args)
# Out:
# terminal
# Run shell commands on this Windows machine.
# {'commands': {'anyOf': [{'type': 'string'}, {'items': {'type': 'string'}, 'type': 'array'}], 'description': 'List of shell commands to run. Deserialized using json.loads', 'title': 'Commands'}}

# %% [markdown]
# ### Wikipedia
#
# The Wikipedia tool in LangChain is a way to give access to information stored on Wikipedia. Since LLMs can’t directly fetch live or structured knowledge, the Wikipedia tool acts as a bridge. It queries Wikipedia, retrieves summaries or articles, and returns them as text the agent can use in reasoning.
#
# To use it, first install: !pip install -qU  wikipedia

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

wiki_tool = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())

result = wiki_tool.invoke("LLM")
# Out:
# d:\GENAIBatch\langchain_new\.venv\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file d:\GENAIBatch\langchain_new\.venv\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
print(result)
# Out:
# Page: Large language model
# Summary: A large language model (LLM) is a computational model designed to perform natural language processing tasks, especially language generation, using contextual relationships derived from a large set of training data. LLMs can generate, summarize, translate and parse text in a variety of contexts, and are the technological underpinning of modern chatbots. LLMs can accurately mimic natural language patterns because they are trained on collections of human-written text. For the same reason, biased or inaccurate training data can make a LLM's output less reliable.
# As of 2024, the largest and most capable LLMs are all based on transformer architectures, which can be more efficient and parallelizable than earlier statistical and recurrent neural network models. Research into other architectures, such as state space models, is ongoing.
# Models like GPT, BERT, and their successors used these advances to demonstrate emergent behaviors at scale, such as finding specific data from a large data set and compositional reasoning.
# Benchmark evaluations for LLMs test a model's ability to perform one or more language tasks. Modern LLMs may face comprehensive, multi-task evaluations measuring reasoning, factual accuracy, alignment, and safety. Optimizing training sessions to pass benchmarks may result in a model that adheres too closely to benchmark outputs without genuine generalization or robust capability improvements.
#
# Page: List of large language models
# Summary: A large language model (LLM) is a type of machine learning model designed for natural language processing tasks such as language generation. LLMs are language models with many parameters, and are trained with self-supervised learning on a vast amount of text.

# %% [markdown]
# ### Custom Tool

# %% [markdown]
# ##### Tool Creation with @tool decorator

# %%
# Import tool class from langchain
from langchain_core.tools import tool

# %%
# Create your own function
# Doc string is highly recomended it will helps llm to what to do.
def multiply(a,b):
    '''Multiply two numbers'''
    return a*b

# %%
# Add type hints
def multiply(a:int,b:int) -> int:
    '''Multiply two numbers'''
    return a*b

# %%
# add tool decorator

@tool
def multiply(a:int,b:int) -> int:
    '''Multiply two numbers'''
    return a*b

# %%
result = multiply.invoke({"a":5,"b":6})
result
# Out:
# 30

# %%
# Basic information 
print(multiply.name)
# Out:
# multiply

# %%
# Basic information 
print(multiply.description)
# Out:
# Multiply two numbers

# %%
# Basic information 
print(multiply.args)
# Out:
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
# Basic information 
print(multiply.args_schema)
# Out:
# <class 'langchain_core.utils.pydantic.multiply'>

# %%
print(multiply.args_schema.model_json_schema())
# Out:
# {'description': 'Multiply two numbers', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'multiply', 'type': 'object'}

# %% [markdown]
# ##### Tool Creation with Pydantic - Structured Tool

# %%
from langchain_core.tools import StructuredTool
from pydantic import BaseModel, Field

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Define a Pydantic model for the tool's arguments
class MultiplyArgs(BaseModel):
    a: int = Field(required=True, description="The first number to multiply")
    b: int = Field(required=True, description="The second number to multiply")

# %%
# Define the function that performs the multiplication
def multiply(a: int, b: int) -> int:
    '''Multiply two numbers'''
    return a * b

# %%
# Create a StructuredTool using the function and the argument schema
# important to provide description for the tool, it will helps llm to understand when to use this tool.
# The main tool creation happens here, we are creating a tool from a function and providing the argument schema and description.
multiply_tool = StructuredTool.from_function(
    func=multiply,
    name="multiply",
    args_schema=MultiplyArgs,
    description="Multiplies two numbers together."
)

# %%
# test the tool
result = multiply_tool.invoke({"a":5,"b":6})
print(result)
# Out:
# 30

# %%
# Basic information of tool
print(multiply_tool.name)
print(multiply_tool.description)
print(multiply_tool.args)
# Out:
# multiply
# Multiplies two numbers together.
# {'a': {'description': 'The first number to multiply', 'title': 'A', 'type': 'integer'}, 'b': {'description': 'The second number to multiply', 'title': 'B', 'type': 'integer'}}

# %% [markdown]
# ##### Tool creation using BaseTool Class

# %%
from langchain_core.tools import BaseTool
from pydantic import BaseModel, Field
from typing import Type

# %%
# Define the input schema for the tool

class AddArgs(BaseModel):
    a: int = Field(required=True, description="The first number to add")
    b: int = Field(required=True, description="The second number to add")

# %%
# Define a custom tool by inheriting from BaseTool
class AdditionTool(BaseTool):
    name: str = "addition"
    description: str = "Adds two numbers together."
    args_schema: Type[BaseModel] = AddArgs

    def _run(self, a: int, b: int) -> int:
        '''Add two numbers'''
        return a + b

# %%
# Create an instance of the tool
addition_tool = AdditionTool()

result = addition_tool.invoke({"a":5,"b":6})

print(result)
# Out:
# 11

# %%
# Basic information
print(addition_tool.name)
print(addition_tool.description)
print(addition_tool.args)
# Out:
# addition
# Adds two numbers together.
# {'a': {'description': 'The first number to add', 'title': 'A', 'type': 'integer'}, 'b': {'description': 'The second number to add', 'title': 'B', 'type': 'integer'}}

# %% [markdown]
# #### Toolkits

# %% [markdown]
# - A toolkit is just a collection(bundle) of related tools that surves a common purpose - packaged together for convenience and reusability.
# - For example - CalculatorTool
#     - add
#     - sub
#     - mul
#     - div
# - In langchain, GoogleDriveToolKit
#     - GoogleDriveCreateFileTool - upload a file
#     - GoogleDriveSearchFileTool - search for a file by name or tool
#     - GoogleDriveReadFileTool - Read content of a file

# %%
from langchain_core.tools import tool

@tool
def subtract(a: int, b: int) -> int:
    '''Subtract two numbers'''
    return a - b

@tool
def divide(a: int, b: int) -> float:
    '''Divide two numbers'''
    if b == 0:
        raise ValueError("Cannot divide by zero")
    return a / b

@tool
def power(a: int, b: int) -> int:
    '''Raise a to the power of b'''
    return a ** b

@tool
def modulus(a: int, b: int) -> int:
    '''Get the modulus of a and b'''
    if b == 0:
        raise ValueError("Cannot modulus by zero")
    return a % b

@tool
def floor_divide(a: int, b: int) -> int:
    '''Floor divide a by b'''
    if b == 0:
        raise ValueError("Cannot floor divide by zero")
    return a // b

@tool
def addition(a: int, b: int) -> int:
    '''Add two numbers'''
    return a + b

# %%
# Create a tool kit to group all the tools together, it will helps llm to find the right tool when needed.
class CalculatorToolKit:
    def get_tools(self):
        return [addition, subtract, divide, power, modulus, floor_divide]

# %%
# Create an instance of the tool
calculator_toolkit = CalculatorToolKit()
tools = calculator_toolkit.get_tools()
tools
# Out:
# [StructuredTool(name='addition', description='Add two numbers', args_schema=<class 'langchain_core.utils.pydantic.addition'>, func=<function addition at 0x000001BEFC5E3380>),
#  StructuredTool(name='subtract', description='Subtract two numbers', args_schema=<class 'langchain_core.utils.pydantic.subtract'>, func=<function subtract at 0x000001BEFC5E31A0>),
#  StructuredTool(name='divide', description='Divide two numbers', args_schema=<class 'langchain_core.utils.pydantic.divide'>, func=<function divide at 0x000001BEFC5E3EC0>),
#  StructuredTool(name='power', description='Raise a to the power of b', args_schema=<class 'langchain_core.utils.pydantic.power'>, func=<function power at 0x000001BEFC5E3740>),
#  StructuredTool(name='modulus', description='Get the modulus of a and b', args_schema=<class 'langchain_core.utils.pydantic.modulus'>, func=<function modulus at 0x000001BEFC5E36A0>),
#  StructuredTool(name='floor_divide', description='Floor divide a by b', args_schema=<class 'langchain_core.utils.pydantic.floor_divide'>, func=<function floor_divide at 0x000001BEFC5E3560>)]

# %% [markdown]
# #### Connecting Tools with LLM

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
import os

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
# Define a addition tool using the tool decorator

@tool
def addition(a: int, b: int) -> int:
    '''Given two numbers a and b, return their sum.'''
    return a + b

# %%
addition.name
# Out:
# 'addition'

# %%
addition.description
# Out:
# 'Given two numbers a and b, return their sum.'

# %%
addition.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool bindings

llm_with_tools = llm.bind_tools([addition])

# %%
# tool bindings
llm_with_tools
# Out:
# RunnableBinding(bound=ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001BEA44AA120>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001BEA44AAE40>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'addition', 'description': 'Given two numbers a and b, return their sum.', 'parameters': {'properties': {'a': {'type': 'integer'}, 'b': {'type': 'integer'}}, 'required': ['a', 'b'], 'type': 'object'}}}]}, config={}, config_factories=[])

# %%
# tool invocation
llm_with_tools.invoke("Hello I am Anant. How are you?")
# Out:
# AIMessage(content="Hello Anant, I'm functioning properly, thank you for asking. I'm here to assist you with any questions or tasks you may have. What would you like to talk about or do today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 238, 'total_tokens': 279, 'completion_time': 0.118563232, 'completion_tokens_details': None, 'prompt_time': 0.213321794, 'prompt_tokens_details': None, 'queue_time': 0.113470344, 'total_time': 0.331885026}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d7d3d-d0e1-7101-9a2a-27ebd35617ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 238, 'output_tokens': 41, 'total_tokens': 279})

# %%
# tool invocation
llm_with_tools.invoke("What is the sum of 5 and 6?")
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ryjm8nf83', 'function': {'arguments': '{"a":5,"b":6}', 'name': 'addition'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 239, 'total_tokens': 258, 'completion_time': 0.0232181, 'completion_tokens_details': None, 'prompt_time': 0.018490921, 'prompt_tokens_details': None, 'queue_time': 0.054453129, 'total_time': 0.041709021}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d7d3e-07aa-7c81-8d5a-969054c7e75f-0', tool_calls=[{'name': 'addition', 'args': {'a': 5, 'b': 6}, 'id': 'ryjm8nf83', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 239, 'output_tokens': 19, 'total_tokens': 258})

# %%
# tool invocation with tool calls
llm_with_tools.invoke("What is the sum of 5 and 6?").tool_calls
# Out:
# [{'name': 'addition',
#   'args': {'a': 5, 'b': 6},
#   'id': 'ybsxs43xr',
#   'type': 'tool_call'}]

# %%
addition.invoke(llm_with_tools.invoke("What is the sum of 5 and 6?").tool_calls[0])
# Out:
# ToolMessage(content='11', name='addition', tool_call_id='bc3jxz01e')

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
query = HumanMessage(content="What is the sum of 5 and 6?")
messages = [query]
messages
# Out:
# [HumanMessage(content='What is the sum of 5 and 6?', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke("What is the sum of 5 and 6?")
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='What is the sum of 5 and 6?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'j878strfs', 'function': {'arguments': '{"a":5,"b":6}', 'name': 'addition'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 239, 'total_tokens': 258, 'completion_time': 0.023215641, 'completion_tokens_details': None, 'prompt_time': 0.030879601, 'prompt_tokens_details': None, 'queue_time': 0.051891239, 'total_time': 0.054095242}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d7d3f-de98-78f1-a6f7-1a214cb02057-0', tool_calls=[{'name': 'addition', 'args': {'a': 5, 'b': 6}, 'id': 'j878strfs', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 239, 'output_tokens': 19, 'total_tokens': 258})]

# %%
tool_results = addition.invoke(result.tool_calls[0])
tool_results
# Out:
# ToolMessage(content='11', name='addition', tool_call_id='j878strfs')

# %%
messages.append(tool_results)
messages
# Out:
# [HumanMessage(content='What is the sum of 5 and 6?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'j878strfs', 'function': {'arguments': '{"a":5,"b":6}', 'name': 'addition'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 239, 'total_tokens': 258, 'completion_time': 0.023215641, 'completion_tokens_details': None, 'prompt_time': 0.030879601, 'prompt_tokens_details': None, 'queue_time': 0.051891239, 'total_time': 0.054095242}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d7d3f-de98-78f1-a6f7-1a214cb02057-0', tool_calls=[{'name': 'addition', 'args': {'a': 5, 'b': 6}, 'id': 'j878strfs', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 239, 'output_tokens': 19, 'total_tokens': 258}),
#  ToolMessage(content='11', name='addition', tool_call_id='j878strfs')]

# %%
print(llm_with_tools.invoke(messages).content)
# Out:
# The sum of 5 and 6 is 11.
